# %% [markdown]
# # Trial Averaging

# %% [markdown]
# ## Load data

# %%
import os, sys
filename = os.path.join(os.path.expanduser('~'), 'Desktop', '2024_10_07-17-18-53.nwb')

sys.path.append(os.path.join(os.path.expanduser('~'), 'work', 'physion', 'src'))
import physion
data = physion.analysis.read_NWB.Data(filename,
                                     verbose=False)

# %% [markdown]
# ## Build episodes (stimulus-aligned)

# %%
episodes = physion.analysis.process_NWB.EpisodeData(data, 
                                                    quantities=['dFoF'],
                                                    protocol_id=0)
# Out:
#   Number of episodes over the whole recording: 240/240 (with protocol condition)
#   building episodes with 1 modalities [...]
#
# calculating dF/F with method "percentile" [...]
#
#   ** 12 ROIs were discarded with the positive F0 criterion (27.9%) **
#
# -> dFoF calculus done !  (calculation took 0.0s)
#   -> [ok] episodes ready !

# %% [markdown]
# ## Plot properties

# %%
plot_props = dict(column_key='angle',
                  with_annotation=True,
                  figsize=(9,1.8))

# %% [markdown]
# ## Average over all ROIs

# %%
fig, AX = physion.dataviz.episodes.trial_average.plot(episodes,
                                                      roiIndices='all',
                                                      **plot_props)
# Out:
# X-bar label automatically set to:  0.7  Using the format %.1f  --> adjust it and add units through the format !
# Y-bar label automatically set to:  0.8  Using the format %.1f  --> adjust it and add units through the format !

# %% [markdown]
# ## Single ROIs

# %%
fig, AX = physion.dataviz.episodes.trial_average.plot(episodes,
                                                      roiIndex=0,
                                                      **plot_props)
# Out:
# X-bar label automatically set to:  0.7  Using the format %.1f  --> adjust it and add units through the format !
# Y-bar label automatically set to:  0.2  Using the format %.1f  --> adjust it and add units through the format !

# %%
fig, AX = physion.dataviz.episodes.trial_average.plot(episodes,
                                                      roiIndex=2,
                                                      **plot_props)
